# %%
# !pip install requests beautifulsoup4 pandas openpyxl
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Define the base URL of the website
base_url = "https://www.vezeeta.com/en/doctor/dermatology/egypt?SortByValue=1"

# Headers for the request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

data = []
page = 1

while True:
    # Construct the URL for the current page
    url = base_url + str(page)
    response = requests.get(url, headers=headers)

    # Break the loop if the request fails
    if response.status_code != 200:
        print(f"No more pages to scrape. Stopped at page {page}.")
        break

    soup = BeautifulSoup(response.content, "html.parser")

    # Find all doctor cards on the current page
    doctors = soup.find_all("div", class_="DoctorCardSubComponentsstyle__DoctorImgContainer-sc-1vq3h7c-9")
    if not doctors:
        print("No more doctors found. Exiting loop.")
        break

    for index, doctor in enumerate(doctors):
        # Extract image URL safely
        image_section = doctor.find("img")
        image_url = image_section.get("src") if image_section and image_section.has_attr("src") else None

        # Extract doctor details
        name_section = doctor.find_next("h4")
        name = name_section.text.strip() if name_section else None

        description_section = doctor.find_next("p")
        description = description_section.text.strip() if description_section else None

        rating_section = doctor.find_next("span", class_="StarRatingstyle__StarRatingContainer-sc-16vjtpf-0")
        rating = rating_section.text.strip() if rating_section else None

        # Extract other information
        fees_section = doctor.find_next("span", {"data-testid": f"doctor-card-{index}_fees-row_value"})
        fees = fees_section.text.strip() if fees_section else None

        waiting_time_section = doctor.find_next("span", {"data-testid": f"doctor-card-{index}_waiting-time"})
        waiting_time = waiting_time_section.text.strip() if waiting_time_section else None

        clinic_section = doctor.find_next("span", {"data-testid": f"doctor-card-{index}_address"})
        clinic_name = clinic_section.text.strip() if clinic_section else None

        contact_section = doctor.find_next("a", {"data-testid": f"doctor-card-{index}_hotline-row"})
        contact_number = contact_section.text.strip() if contact_section else None

        # Append data
        data.append({
            "Doctor Name": name,
            "Description": description,
            "Rating": rating,
            "Fees": fees,
            "Waiting Time": waiting_time,
            "Clinic Name": clinic_name,
            "Contact Number": contact_number,
            "Image URL": image_url,
        })

    print(f"Page {page} scraped successfully.")
    page += 1

# Create a DataFrame
df = pd.DataFrame(data)

# Save the data to an Excel file
excel_filename = "doctors_data.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Data has been successfully scraped and saved to {excel_filename}.")
# Out:
# Page 1 scraped successfully.
# Page 2 scraped successfully.
# Page 3 scraped successfully.
# Page 4 scraped successfully.
# Page 5 scraped successfully.
# Page 6 scraped successfully.
# Page 7 scraped successfully.
# Page 8 scraped successfully.
# Page 9 scraped successfully.
# Page 10 scraped successfully.
# Page 11 scraped successfully.
# Page 12 scraped successfully.
# Page 13 scraped successfully.
# Page 14 scraped successfully.
# Page 15 scraped successfully.
# Page 16 scraped successfully.
# Page 17 scraped successfully.
# Page 18 scraped successfully.
# Page 19 scraped successfully.
# Page 20 scraped successfully.
# Page 21 scraped successfully.
# Page 22 scraped successfully.
# Page 23 scraped successfully.
# Page 24 scraped successfully.
# Page 25 scraped successfully.
# Page 26 scraped successfully.
# Page 27 scraped successfully.
# Page 28 scraped successfully.
# Page 29 scraped successfully.
# Page 30 scraped successfully.
# Page 31 scraped successfully.
# Page 32 scraped successfully.
# Page 33 scraped successfully.
# Page 34 scraped successfully.
# Page 35 scraped successfully.
# Page 36 scraped successfully.
# Page 37 scraped successfully.
# Page 38 scraped successfully.
# Page 39 scraped successfully.
# Page 40 scraped successfully.
# Page 41 scraped successfully.
# Page 42 scraped successfully.
# Page 43 scraped successfully.
# Page 44 scraped successfully.
# Page 45 scraped successfully.
# Page 46 scraped successfully.
# Page 47 scraped successfully.
# Page 48 scraped successfully.
# Page 49 scraped successfully.
# Page 50 scraped successfully.
# Page 51 scraped successfully.
# Page 52 scraped successfully.
# Page 53 scraped successfully.
# Page 54 scraped successfully.
# Page 55 scraped successfully.
# Page 56 scraped successfully.
# Page 57 scraped successfully.
# Page 58 scraped successfully.
# Page 59 scraped successfully.
# Page 60 scraped successfully.
# Page 61 scraped successfully.
# Page 62 scraped successfully.
# Page 63 scraped successfully.
# Page 64 scraped successfully.
# Page 65 scraped successfully.
# Page 66 scraped successfully.
# Page 67 scraped successfully.
# Page 68 scraped successfully.
# Page 69 scraped successfully.
# Page 70 scraped successfully.
# Page 71 scraped successfully.
# Page 72 scraped successfully.
# Page 73 scraped successfully.
# Page 74 scraped successfully.
# Page 75 scraped successfully.
# Page 76 scraped successfully.
# Page 77 scraped successfully.
# Page 78 scraped successfully.
# Page 79 scraped successfully.
# Page 80 scraped successfully.
# Page 81 scraped successfully.
# Page 82 scraped successfully.
# Page 83 scraped successfully.
# Page 84 scraped successfully.
# Page 85 scraped successfully.
# Page 86 scraped successfully.
# Page 87 scraped successfully.
# Page 88 scraped successfully.
# Page 89 scraped successfully.
# Page 90 scraped successfully.
# Page 91 scraped successfully.
# Page 92 scraped successfully.
# Page 93 scraped successfully.
# Page 94 scraped successfully.
# Page 95 scraped successfully.
# Page 96 scraped successfully.
# Page 97 scraped successfully.
# Page 98 scraped successfully.
# Page 99 scraped successfully.
# Page 100 scraped successfully.
# Page 101 scraped successfully.
# Page 102 scraped successfully.
# Page 103 scraped successfully.
# Page 104 scraped successfully.
# Page 105 scraped successfully.
# Page 106 scraped successfully.
# Page 107 scraped successfully.
# Page 108 scraped successfully.
# Page 109 scraped successfully.
# Page 110 scraped successfully.
# Page 111 scraped successfully.
# Page 112 scraped successfully.
# Page 113 scraped successfully.
# Page 114 scraped successfully.
# Page 115 scraped successfully.
# Page 116 scraped successfully.
# Page 117 scraped successfully.
# Page 118 scraped successfully.
# Page 119 scraped successfully.
# Page 120 scraped successfully.
# Page 121 scraped successfully.
# Page 122 scraped successfully.
# Page 123 scraped successfully.
# Page 124 scraped successfully.
# Page 125 scraped successfully.
# Page 126 scraped successfully.
# Page 127 scraped successfully.
# Page 128 scraped successfully.
# Page 129 scraped successfully.
# Page 130 scraped successfully.
# Page 131 scraped successfully.
# Page 132 scraped successfully.
# Page 133 scraped successfully.
# Page 134 scraped successfully.
# Page 135 scraped successfully.
# Page 136 scraped successfully.
# Page 137 scraped successfully.
# Page 138 scraped successfully.
# Page 139 scraped successfully.
# Page 140 scraped successfully.
# Page 141 scraped successfully.
# Page 142 scraped successfully.
# Page 143 scraped successfully.
# Page 144 scraped successfully.
# Page 145 scraped successfully.
# Page 146 scraped successfully.
# Page 147 scraped successfully.
# Page 148 scraped successfully.
# Page 149 scraped successfully.
# Page 150 scraped successfully.
# Page 151 scraped successfully.
# Page 152 scraped successfully.
# Page 153 scraped successfully.
# Page 154 scraped successfully.
# Page 155 scraped successfully.
# Page 156 scraped successfully.
# Page 157 scraped successfully.
# Page 158 scraped successfully.
# Page 159 scraped successfully.
# Page 160 scraped successfully.
# Page 161 scraped successfully.
# Page 162 scraped successfully.
# Page 163 scraped successfully.
# Page 164 scraped successfully.
# Page 165 scraped successfully.
# Page 166 scraped successfully.
# Page 167 scraped successfully.
# Page 168 scraped successfully.
# Page 169 scraped successfully.
# Page 170 scraped successfully.
# Page 171 scraped successfully.
# Page 172 scraped successfully.
# Page 173 scraped successfully.
# Page 174 scraped successfully.
# Page 175 scraped successfully.
# Page 176 scraped successfully.
# Page 177 scraped successfully.
# Page 178 scraped successfully.
# Page 179 scraped successfully.
# Page 180 scraped successfully.
# Page 181 scraped successfully.
# Page 182 scraped successfully.
# Page 183 scraped successfully.
# Page 184 scraped successfully.
# Page 185 scraped successfully.
# Page 186 scraped successfully.
# Page 187 scraped successfully.
# Page 188 scraped successfully.
# Page 189 scraped successfully.
# Page 190 scraped successfully.
# Page 191 scraped successfully.
# Page 192 scraped successfully.
# Page 193 scraped successfully.
# Page 194 scraped successfully.
# Page 195 scraped successfully.
# Page 196 scraped successfully.
# Page 197 scraped successfully.
# Page 198 scraped successfully.
# Page 199 scraped successfully.
# Page 200 scraped successfully.
# Page 201 scraped successfully.
# Page 202 scraped successfully.
# Page 203 scraped successfully.
# Page 204 scraped successfully.
# Page 205 scraped successfully.
# Page 206 scraped successfully.
# Page 207 scraped successfully.
# Page 208 scraped successfully.
# Page 209 scraped successfully.
# Page 210 scraped successfully.
# Page 211 scraped successfully.
# Page 212 scraped successfully.
# Page 213 scraped successfully.
# Page 214 scraped successfully.
# Page 215 scraped successfully.
# Page 216 scraped successfully.
# Page 217 scraped successfully.
# Page 218 scraped successfully.
# Page 219 scraped successfully.
# Page 220 scraped successfully.
# Page 221 scraped successfully.
# Page 222 scraped successfully.
# Page 223 scraped successfully.
# Page 224 scraped successfully.
# Page 225 scraped successfully.
# Page 226 scraped successfully.
# Page 227 scraped successfully.
# Page 228 scraped successfully.
# Page 229 scraped successfully.
# Page 230 scraped successfully.
# Page 231 scraped successfully.
# Page 232 scraped successfully.
# Page 233 scraped successfully.
# Page 234 scraped successfully.
# Page 235 scraped successfully.
# Page 236 scraped successfully.
# Page 237 scraped successfully.
# Page 238 scraped successfully.
# Page 239 scraped successfully.
# Page 240 scraped successfully.
# Page 241 scraped successfully.
# Page 242 scraped successfully.
# Page 243 scraped successfully.
# Page 244 scraped successfully.
# Page 245 scraped successfully.
# Page 246 scraped successfully.
# Page 247 scraped successfully.
# Page 248 scraped successfully.
# Page 249 scraped successfully.
# Page 250 scraped successfully.
# Page 251 scraped successfully.
# Page 252 scraped successfully.
# Page 253 scraped successfully.
# Page 254 scraped successfully.
# Page 255 scraped successfully.
# Page 256 scraped successfully.
# Page 257 scraped successfully.
# Page 258 scraped successfully.
# Page 259 scraped successfully.
# Page 260 scraped successfully.
# Page 261 scraped successfully.
# Page 262 scraped successfully.
# Page 263 scraped successfully.
# Page 264 scraped successfully.
# Page 265 scraped successfully.
# Page 266 scraped successfully.
# Page 267 scraped successfully.
# Page 268 scraped successfully.
# Page 269 scraped successfully.
# Page 270 scraped successfully.
# Page 271 scraped successfully.
# Page 272 scraped successfully.
# Page 273 scraped successfully.
# Page 274 scraped successfully.
# Page 275 scraped successfully.
# Page 276 scraped successfully.
# Page 277 scraped successfully.
# Page 278 scraped successfully.
# Page 279 scraped successfully.
# Page 280 scraped successfully.
# Page 281 scraped successfully.
# Page 282 scraped successfully.
# Page 283 scraped successfully.
# Page 284 scraped successfully.
# Page 285 scraped successfully.
# Page 286 scraped successfully.
# Page 287 scraped successfully.
# Page 288 scraped successfully.
# Page 289 scraped successfully.
# Page 290 scraped successfully.
# Page 291 scraped successfully.
# Page 292 scraped successfully.
# Page 293 scraped successfully.
# Page 294 scraped successfully.
# Page 295 scraped successfully.
# Page 296 scraped successfully.
# Page 297 scraped successfully.
# Page 298 scraped successfully.
# Page 299 scraped successfully.
# Page 300 scraped successfully.
# Page 301 scraped successfully.
# Page 302 scraped successfully.
# Page 303 scraped successfully.
# Page 304 scraped successfully.
# Page 305 scraped successfully.
# Page 306 scraped successfully.
# Page 307 scraped successfully.
# Page 308 scraped successfully.
# Page 309 scraped successfully.
# Page 310 scraped successfully.
# Page 311 scraped successfully.
# Page 312 scraped successfully.
# Page 313 scraped successfully.
# Page 314 scraped successfully.
# Page 315 scraped successfully.
# Page 316 scraped successfully.
# Page 317 scraped successfully.
# Page 318 scraped successfully.
# Page 319 scraped successfully.
# Page 320 scraped successfully.
# Page 321 scraped successfully.
# Page 322 scraped successfully.
# Page 323 scraped successfully.
# Page 324 scraped successfully.
# Page 325 scraped successfully.
# Page 326 scraped successfully.
# Page 327 scraped successfully.
# Page 328 scraped successfully.
# Page 329 scraped successfully.
# Page 330 scraped successfully.
# Page 331 scraped successfully.
# Page 332 scraped successfully.
# Page 333 scraped successfully.
# Page 334 scraped successfully.
# Page 335 scraped successfully.
# Page 336 scraped successfully.
# Page 337 scraped successfully.
# Page 338 scraped successfully.
# Page 339 scraped successfully.
# Page 340 scraped successfully.
# Page 341 scraped successfully.
# Page 342 scraped successfully.
# Page 343 scraped successfully.
# Page 344 scraped successfully.
# Page 345 scraped successfully.
# Page 346 scraped successfully.
# Page 347 scraped successfully.
# Page 348 scraped successfully.
# Page 349 scraped successfully.
# Page 350 scraped successfully.
# Page 351 scraped successfully.
# Page 352 scraped successfully.
# Page 353 scraped successfully.
# Page 354 scraped successfully.
# Page 355 scraped successfully.
# Page 356 scraped successfully.
# Page 357 scraped successfully.
# Page 358 scraped successfully.
# Page 359 scraped successfully.
# Page 360 scraped successfully.
# Page 361 scraped successfully.
# Page 362 scraped successfully.
# Page 363 scraped successfully.
# Page 364 scraped successfully.
# Page 365 scraped successfully.
# Page 366 scraped successfully.
# Page 367 scraped successfully.
# Page 368 scraped successfully.
# Page 369 scraped successfully.
# Page 370 scraped successfully.
# Page 371 scraped successfully.
# Page 372 scraped successfully.
# Page 373 scraped successfully.
# Page 374 scraped successfully.
# Page 375 scraped successfully.
# Page 376 scraped successfully.
# Page 377 scraped successfully.
# Page 378 scraped successfully.
# Page 379 scraped successfully.
# Page 380 scraped successfully.
# Page 381 scraped successfully.
# Page 382 scraped successfully.
# Page 383 scraped successfully.
# Page 384 scraped successfully.
# Page 385 scraped successfully.
# Page 386 scraped successfully.
# Page 387 scraped successfully.
# Page 388 scraped successfully.
# Page 389 scraped successfully.
# Page 390 scraped successfully.
# Page 391 scraped successfully.
# Page 392 scraped successfully.
# Page 393 scraped successfully.
# Page 394 scraped successfully.
# Page 395 scraped successfully.
# Page 396 scraped successfully.
# Page 397 scraped successfully.
# Page 398 scraped successfully.
# Page 399 scraped successfully.
# Page 400 scraped successfully.
# Page 401 scraped successfully.
# Page 402 scraped successfully.
# Page 403 scraped successfully.
# Page 404 scraped successfully.
# Page 405 scraped successfully.
# Page 406 scraped successfully.
# Page 407 scraped successfully.
# Page 408 scraped successfully.
# Page 409 scraped successfully.
# Page 410 scraped successfully.
# Page 411 scraped successfully.
# Page 412 scraped successfully.
# Page 413 scraped successfully.
# Page 414 scraped successfully.
# Page 415 scraped successfully.
# Page 416 scraped successfully.
# Page 417 scraped successfully.
# Page 418 scraped successfully.
# Page 419 scraped successfully.
# Page 420 scraped successfully.
# Page 421 scraped successfully.
# Page 422 scraped successfully.
# Page 423 scraped successfully.
# Page 424 scraped successfully.
# Page 425 scraped successfully.
# Page 426 scraped successfully.
# Page 427 scraped successfully.
# Page 428 scraped successfully.
# Page 429 scraped successfully.
# Page 430 scraped successfully.
# Page 431 scraped successfully.
# Page 432 scraped successfully.
# Page 433 scraped successfully.
# Page 434 scraped successfully.
# Page 435 scraped successfully.
# Page 436 scraped successfully.
# Page 437 scraped successfully.
# Page 438 scraped successfully.
# Page 439 scraped successfully.
# Page 440 scraped successfully.
# Page 441 scraped successfully.
# Page 442 scraped successfully.
# Page 443 scraped successfully.
# Page 444 scraped successfully.
# Page 445 scraped successfully.
# Page 446 scraped successfully.
# Page 447 scraped successfully.
# Page 448 scraped successfully.
# Page 449 scraped successfully.
# Page 450 scraped successfully.
# Page 451 scraped successfully.
# Page 452 scraped successfully.
# Page 453 scraped successfully.
# Page 454 scraped successfully.
# Page 455 scraped successfully.
# Page 456 scraped successfully.
# Page 457 scraped successfully.
# Page 458 scraped successfully.
# Page 459 scraped successfully.
# Page 460 scraped successfully.
# Page 461 scraped successfully.
# Page 462 scraped successfully.
# Page 463 scraped successfully.
# Page 464 scraped successfully.
# Page 465 scraped successfully.
# Page 466 scraped successfully.
# Page 467 scraped successfully.
# Page 468 scraped successfully.
# Page 469 scraped successfully.
# Page 470 scraped successfully.
# Page 471 scraped successfully.
# Page 472 scraped successfully.
# Page 473 scraped successfully.
# Page 474 scraped successfully.
# Page 475 scraped successfully.
# Page 476 scraped successfully.
# Page 477 scraped successfully.
# Page 478 scraped successfully.
# Page 479 scraped successfully.
# Page 480 scraped successfully.
# Page 481 scraped successfully.
# Page 482 scraped successfully.
# Page 483 scraped successfully.
# Page 484 scraped successfully.
# Page 485 scraped successfully.
# Page 486 scraped successfully.
# Page 487 scraped successfully.
# Page 488 scraped successfully.
# Page 489 scraped successfully.
# Page 490 scraped successfully.
# Page 491 scraped successfully.
# Page 492 scraped successfully.
# Page 493 scraped successfully.
# Page 494 scraped successfully.
# Page 495 scraped successfully.
# Page 496 scraped successfully.
# Page 497 scraped successfully.
# Page 498 scraped successfully.
# Page 499 scraped successfully.
# Page 500 scraped successfully.
# Page 501 scraped successfully.
# Page 502 scraped successfully.
# Page 503 scraped successfully.
# Page 504 scraped successfully.
# Page 505 scraped successfully.
# Page 506 scraped successfully.
# Page 507 scraped successfully.
# Page 508 scraped successfully.
# Page 509 scraped successfully.
# Page 510 scraped successfully.
# Page 511 scraped successfully.
# Page 512 scraped successfully.
# Page 513 scraped successfully.
# Page 514 scraped successfully.
# Page 515 scraped successfully.
# Page 516 scraped successfully.
# Page 517 scraped successfully.
# Page 518 scraped successfully.
# Page 519 scraped successfully.
# Page 520 scraped successfully.
# Page 521 scraped successfully.
# Page 522 scraped successfully.
# Page 523 scraped successfully.
# Page 524 scraped successfully.
# Page 525 scraped successfully.
# Page 526 scraped successfully.
# Page 527 scraped successfully.
# Page 528 scraped successfully.
# Page 529 scraped successfully.
# Page 530 scraped successfully.
# Page 531 scraped successfully.
# Page 532 scraped successfully.
# Page 533 scraped successfully.
# Page 534 scraped successfully.
# Page 535 scraped successfully.
# Page 536 scraped successfully.
# Page 537 scraped successfully.
# Page 538 scraped successfully.
# Page 539 scraped successfully.
# Page 540 scraped successfully.
# Page 541 scraped successfully.
# Page 542 scraped successfully.
# Page 543 scraped successfully.
# Page 544 scraped successfully.
# Page 545 scraped successfully.
# Page 546 scraped successfully.
# Page 547 scraped successfully.
# Page 548 scraped successfully.
# Page 549 scraped successfully.
# Page 550 scraped successfully.
# Page 551 scraped successfully.
# Page 552 scraped successfully.
# Page 553 scraped successfully.
# Page 554 scraped successfully.
# Page 555 scraped successfully.
# Page 556 scraped successfully.
# Page 557 scraped successfully.
# Page 558 scraped successfully.
# Page 559 scraped successfully.
# Page 560 scraped successfully.
# Page 561 scraped successfully.
# Page 562 scraped successfully.
# Page 563 scraped successfully.
# Page 564 scraped successfully.
# Page 565 scraped successfully.
# Page 566 scraped successfully.
# Page 567 scraped successfully.
# Page 568 scraped successfully.
# Page 569 scraped successfully.
# Page 570 scraped successfully.
# Page 571 scraped successfully.
# Page 572 scraped successfully.
# Page 573 scraped successfully.
# Page 574 scraped successfully.
# Page 575 scraped successfully.
# Page 576 scraped successfully.
# Page 577 scraped successfully.
# Page 578 scraped successfully.
# Page 579 scraped successfully.
# Page 580 scraped successfully.
# Page 581 scraped successfully.
# Page 582 scraped successfully.
# Page 583 scraped successfully.
# Page 584 scraped successfully.
# Page 585 scraped successfully.
# Page 586 scraped successfully.
# Page 587 scraped successfully.
# Page 588 scraped successfully.
# Page 589 scraped successfully.
# Page 590 scraped successfully.
# Page 591 scraped successfully.
# Page 592 scraped successfully.
# Page 593 scraped successfully.
# Page 594 scraped successfully.
# Page 595 scraped successfully.
# Page 596 scraped successfully.
# Page 597 scraped successfully.
# Page 598 scraped successfully.
# Page 599 scraped successfully.
# Page 600 scraped successfully.
# Page 601 scraped successfully.
# Page 602 scraped successfully.
# Page 603 scraped successfully.
# Page 604 scraped successfully.
# Page 605 scraped successfully.
# Page 606 scraped successfully.
# Page 607 scraped successfully.
# Page 608 scraped successfully.
# Page 609 scraped successfully.
# Page 610 scraped successfully.
# Page 611 scraped successfully.
# Page 612 scraped successfully.
# Page 613 scraped successfully.
# Page 614 scraped successfully.
# Page 615 scraped successfully.
# Page 616 scraped successfully.
# Page 617 scraped successfully.
# Page 618 scraped successfully.
# No more pages to scrape. Stopped at page 619.
# Data has been successfully scraped and saved to doctors_data.xlsx.
